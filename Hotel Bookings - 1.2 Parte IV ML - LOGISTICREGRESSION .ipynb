# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_validate
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PowerTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from category_encoders import JamesSteinEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report
from feature_engine.encoding import RareLabelEncoder
import joblib as jb

# %%
df = pd.read_csv('df_changed.csv')

# %%
X = df.drop(['is_canceled'], axis= 1)
y = df['is_canceled']

categorical_variables = X.select_dtypes('object').columns.to_list()
numerical_variables = X.select_dtypes('number').columns.to_list()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.33, random_state= 4)

# %%
df['country'].value_counts(dropna=False, normalize= True).shape
# Out:
# (175,)

# %%
df['country'].value_counts(dropna=False, normalize= True)[0:22].sum()
# Out:
# 0.9496055617593026

# %%
df['country'].value_counts(dropna=False, normalize= True)[0:22].tail()
# Out:
# ISR    0.005809
# RUS    0.005286
# NOR    0.005169
# ROU    0.004097
# FIN    0.003908
# Name: country, dtype: float64

# %%
rare_encoder = RareLabelEncoder(tol= 0.003900, variables= ['country'], replace_with= 'Other Country')
rare_encoder.fit(X_train)
X_train = rare_encoder.transform(X_train)
X_test = rare_encoder.transform(X_test)

X_train['country'].value_counts(dropna=False, normalize= True).shape
# Out:
# (23,)

# %%
X_train['country'].value_counts(dropna=False, normalize= True)
# Out:
# PRT              0.404468
# GBR              0.103536
# FRA              0.088509
# ESP              0.070565
# DEU              0.062958
# Other Country    0.051063
# ITA              0.030780
# IRL              0.028871
# BEL              0.019973
# BRA              0.019046
# NLD              0.018280
# USA              0.016694
# CHE              0.014422
# CN               0.010833
# AUT              0.010753
# SWE              0.008710
# CHN              0.008683
# POL              0.008038
# ISR              0.005497
# RUS              0.005282
# NOR              0.004839
# ROU              0.004113
# FIN              0.004086
# Name: country, dtype: float64

# %%
categorical_variables
# Out:
# ['hotel',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'deposit_type',
#  'customer_type']

# %%
country_variable = [categorical_variables[2]]

# %%
other_variables = []
for i in categorical_variables:
    if i != 'country':
        other_variables.append(i)
    else:
        pass

# %% [markdown]
# #### Testando combinação de  diferentes encoders.

# %%
def encoders_model_results_logreg(encoders_cat, encoders_country, model_):
        
    def differentencoders_model_results(x, y):
        other_variables_pipe = Pipeline([('encoder_other_variables', x)])
        country_pipe = Pipeline([('encoder_country', y)])
        num_pipe = Pipeline([('num_pwr_transf', PowerTransformer()), 
                             ('num_std_scaler', StandardScaler())])
        
        transformer = ColumnTransformer([('other_variables_transf', other_variables_pipe, other_variables),
                                         ('country_transf', country_pipe, country_variable), 
                                         ('num_transf', num_pipe, numerical_variables)])
        
        X_train_transformed = transformer.fit_transform(X_train, y_train)
        X_test_transformed = transformer.transform(X_test)
    
        cv = cross_validate(model_, X_train_transformed, y_train, cv= 10, scoring= ('recall', 'precision', 'f1'), 
                               n_jobs= -1)
        
        print(model_)
        print('Recall:', cv['test_recall'].mean().round(2), 'Precision:', 
              cv['test_precision'].mean().round(2), 'F1-Score:', cv['test_f1'].mean().round(2))
        print('')
    
    for i in encoders_cat:
        for j in encoders_country:
            print(i, ' - other variables      ', j, ' - country variable')                    
            differentencoders_model_results(i, j)

# %%
others = [OneHotEncoder(handle_unknown= 'ignore'), JamesSteinEncoder()]
country = [OneHotEncoder(handle_unknown= 'ignore'), JamesSteinEncoder()]

#Regressão Logística
encoders_model_results_logreg(others, country, LogisticRegression())
# Out:
# OneHotEncoder(handle_unknown='ignore')  - other variables       OneHotEncoder(handle_unknown='ignore')  - country variable
# LogisticRegression()
# Recall: 0.68 Precision: 0.82 F1-Score: 0.74
#
# OneHotEncoder(handle_unknown='ignore')  - other variables       JamesSteinEncoder()  - country variable
# LogisticRegression()
# Recall: 0.68 Precision: 0.82 F1-Score: 0.74
#
# JamesSteinEncoder()  - other variables       OneHotEncoder(handle_unknown='ignore')  - country variable
# LogisticRegression()
# Recall: 0.64 Precision: 0.82 F1-Score: 0.72
#
# JamesSteinEncoder()  - other variables       JamesSteinEncoder()  - country variable
# LogisticRegression()
# Recall: 0.64 Precision: 0.82 F1-Score: 0.72

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### OHE

# %%
pd.set_option('max.colwidth', None)

other_variables_pipe = Pipeline([('encoder_other_variables', OneHotEncoder(handle_unknown= 'ignore'))])
country_pipe = Pipeline([('encoder_country', OneHotEncoder(handle_unknown= 'ignore'))])
num_pipe = Pipeline([('num_pwr_transf', PowerTransformer()), 
                     ('num_std_scaler', StandardScaler())])
   
transformer = ColumnTransformer([('other_variables_transf', other_variables_pipe, other_variables),
                                 ('country_transf', country_pipe, country_variable), 
                                 ('num_transf', num_pipe, numerical_variables)])

logreg = LogisticRegression()

pipe = Pipeline([('transformer', transformer), ('model', logreg)])

weights = np.arange(0.2, 0.8, 0.005)
param_grid = {'model__class_weight':[{0:x, 1:1-x} for x in weights]}

rscv_logreg = RandomizedSearchCV(pipe, param_grid, cv= 10, n_jobs= -1, 
                    scoring= ['recall', 'precision', 'f1', 'roc_auc'], refit= 'f1', return_train_score= True, random_state= 4)

rscv_logreg.fit(X_train, y_train)

best_results = pd.DataFrame(rscv_logreg.cv_results_)

# %%
best_results[['params','mean_train_recall', 'mean_test_recall', 'mean_train_precision', 'mean_test_precision', 
              'mean_train_f1', 'mean_test_f1', 'mean_train_roc_auc', 'mean_test_roc_auc']].sort_values(
                                                                                'mean_test_f1', ascending= False).round(2)
# Out:
#                                                                      params  \
# 2   {'model__class_weight': {0: 0.3250000000000001, 1: 0.6749999999999998}}
# 7   {'model__class_weight': {0: 0.3200000000000001, 1: 0.6799999999999999}}
# 5   {'model__class_weight': {0: 0.4050000000000002, 1: 0.5949999999999998}}
# 9                  {'model__class_weight': {0: 0.3000000000000001, 1: 0.7}}
# 4   {'model__class_weight': {0: 0.2950000000000001, 1: 0.7049999999999998}}
# 3                 {'model__class_weight': {0: 0.2800000000000001, 1: 0.72}}
# 0  {'model__class_weight': {0: 0.26500000000000007, 1: 0.7349999999999999}}
# 6  {'model__class_weight': {0: 0.22500000000000003, 1: 0.7749999999999999}}
# 1                {'model__class_weight': {0: 0.21000000000000002, 1: 0.79}}
# 8   {'model__class_weight': {0: 0.6100000000000003, 1: 0.3899999999999997}}
#
#    mean_train_recall  mean_test_recall  mean_train_precision  \
# 2               0.82              0.82                  0.71
# 7               0.83              0.83                  0.71
# 5               0.76              0.76                  0.76
# 9               0.84              0.84                  0.69
# 4               0.85              0.85                  0.69
# 3               0.86              0.86                  0.67
# 0               0.87              0.87                  0.66
# 6               0.90              0.90                  0.63
# 1               0.91              0.91                  0.62
# 8               0.59              0.59                  0.88
#
#    mean_test_precision  mean_train_f1  mean_test_f1  mean_train_roc_auc  \
# 2                 0.71           0.76          0.76                 0.9
# 7                 0.71           0.76          0.76                 0.9
# 5                 0.76           0.76          0.76                 0.9
# 9                 0.69           0.76          0.76                 0.9
# 4                 0.69           0.76          0.76                 0.9
# 3                 0.67           0.75          0.75                 0.9
# 0                 0.66           0.75          0.75                 0.9
# 6                 0.63           0.74          0.74                 0.9
# 1                 0.62           0.73          0.73                 0.9
# 8                 0.88           0.70          0.70                 0.9
#
#    mean_test_roc_auc
# 2                0.9
# 7                0.9
# 5                0.9
# 9                0.9
# 4                0.9
# 3                0.9
# 0                0.9
# 6                0.9
# 1                0.9
# 8                0.9

# %%
print(rscv_logreg.best_params_)
print('')

logreg_final = rscv_logreg.best_estimator_.fit(X_train, y_train)
y_pred = logreg_final.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
# {'model__class_weight': {0: 0.3250000000000001, 1: 0.6749999999999998}}
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84     23067
#            1       0.71      0.83      0.76     13578
#
#     accuracy                           0.81     36645
#    macro avg       0.80      0.81      0.80     36645
# weighted avg       0.82      0.81      0.81     36645

# %% [markdown]
# ####  OHE + JamesStein

# %%
other_variables_pipe = Pipeline([('encoder_other_variables', OneHotEncoder(handle_unknown= 'ignore'))])
country_pipe = Pipeline([('encoder_country', JamesSteinEncoder())])
num_pipe = Pipeline([('num_pwr_transf', PowerTransformer()), 
                     ('num_std_scaler', StandardScaler())])
   
transformer = ColumnTransformer([('other_variables_transf', other_variables_pipe, other_variables),
                                 ('country_transf', country_pipe, country_variable), 
                                 ('num_transf', num_pipe, numerical_variables)])

logreg = LogisticRegression()

pipe = Pipeline([('transformer', transformer), ('model', logreg)])

weights = np.arange(0.2, 0.8, 0.005)
param_grid = {'model__class_weight':[{0:x, 1:1-x} for x in weights]}

rscv_logreg_jss = RandomizedSearchCV(pipe, param_grid, cv= 10, n_jobs= -1, 
                    scoring= ['recall', 'precision', 'f1', 'roc_auc'], refit= 'f1', return_train_score= True, random_state= 4)

rscv_logreg_jss.fit(X_train, y_train)

best_results = pd.DataFrame(rscv_logreg_jss.cv_results_)

# %%
best_results[['params','mean_train_recall', 'mean_test_recall', 'mean_train_precision', 'mean_test_precision', 
              'mean_train_f1', 'mean_test_f1', 'mean_train_roc_auc', 'mean_test_roc_auc']].sort_values(
                                                                                'mean_test_f1', ascending= False).round(2)
# Out:
#                                                                      params  \
# 2   {'model__class_weight': {0: 0.3250000000000001, 1: 0.6749999999999998}}
# 7   {'model__class_weight': {0: 0.3200000000000001, 1: 0.6799999999999999}}
# 5   {'model__class_weight': {0: 0.4050000000000002, 1: 0.5949999999999998}}
# 9                  {'model__class_weight': {0: 0.3000000000000001, 1: 0.7}}
# 4   {'model__class_weight': {0: 0.2950000000000001, 1: 0.7049999999999998}}
# 3                 {'model__class_weight': {0: 0.2800000000000001, 1: 0.72}}
# 0  {'model__class_weight': {0: 0.26500000000000007, 1: 0.7349999999999999}}
# 6  {'model__class_weight': {0: 0.22500000000000003, 1: 0.7749999999999999}}
# 1                {'model__class_weight': {0: 0.21000000000000002, 1: 0.79}}
# 8   {'model__class_weight': {0: 0.6100000000000003, 1: 0.3899999999999997}}
#
#    mean_train_recall  mean_test_recall  mean_train_precision  \
# 2               0.82              0.82                  0.71
# 7               0.82              0.82                  0.70
# 5               0.75              0.75                  0.76
# 9               0.84              0.84                  0.69
# 4               0.84              0.84                  0.68
# 3               0.86              0.86                  0.67
# 0               0.87              0.87                  0.66
# 6               0.90              0.90                  0.62
# 1               0.91              0.91                  0.61
# 8               0.58              0.58                  0.88
#
#    mean_test_precision  mean_train_f1  mean_test_f1  mean_train_roc_auc  \
# 2                 0.71           0.76          0.76                 0.9
# 7                 0.70           0.76          0.76                 0.9
# 5                 0.76           0.76          0.76                 0.9
# 9                 0.69           0.76          0.76                 0.9
# 4                 0.68           0.76          0.76                 0.9
# 3                 0.67           0.75          0.75                 0.9
# 0                 0.66           0.75          0.75                 0.9
# 6                 0.62           0.74          0.74                 0.9
# 1                 0.61           0.73          0.73                 0.9
# 8                 0.88           0.70          0.70                 0.9
#
#    mean_test_roc_auc
# 2                0.9
# 7                0.9
# 5                0.9
# 9                0.9
# 4                0.9
# 3                0.9
# 0                0.9
# 6                0.9
# 1                0.9
# 8                0.9

# %%
print(rscv_logreg_jss.best_params_)
print('')

y_pred = rscv_logreg_jss.predict(X_test)

print(classification_report(y_test, y_pred))

pd.reset_option('max.colwidth')
# Out:
# {'model__class_weight': {0: 0.3250000000000001, 1: 0.6749999999999998}}
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84     23067
#            1       0.71      0.82      0.76     13578
#
#     accuracy                           0.81     36645
#    macro avg       0.80      0.81      0.80     36645
# weighted avg       0.82      0.81      0.81     36645

# %%
jb.dump(logreg_final, 'logistic_regression_model')
# Out:
# ['logistic_regression_model']

# %% [markdown]
# ### Análise das Features  do modelo

# %%
feature_importance = pd.DataFrame(rscv_logreg.best_estimator_['model'].coef_.T, columns= ['importance'], 
                                  index= rscv_logreg.best_estimator_['transformer'].get_feature_names_out())
feature_importance.sort_values('importance', ascending= False).round(2).style.bar(color=['red', 'green'])
# Out:
# <style type="text/css">
# #T_c93ad_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 100.0%, transparent 100.0%);
# }
# #T_c93ad_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 86.2%, transparent 86.2%);
# }
# #T_c93ad_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 70.1%, transparent 70.1%);
# }
# #T_c93ad_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 64.6%, transparent 64.6%);
# }
# #T_c93ad_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 61.1%, transparent 61.1%);
# }
# #T_c93ad_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 60.7%, transparent 60.7%);
# }
# #T_c93ad_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 56.7%, transparent 56.7%);
# }
# #T_c93ad_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 56.5%, transparent 56.5%);
# }
# #T_c93ad_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 54.3%, transparent 54.3%);
# }
# #T_c93ad_row9_col0, #T_c93ad_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 53.6%, transparent 53.6%);
# }
# #T_c93ad_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 53.4%, transparent 53.4%);
# }
# #T_c93ad_row12_col0, #T_c93ad_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 52.1%, transparent 52.1%);
# }
# #T_c93ad_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 51.0%, transparent 51.0%);
# }
# #T_c93ad_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 50.8%, transparent 50.8%);
# }
# #T_c93ad_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 49.5%, transparent 49.5%);
# }
# #T_c93ad_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 48.6%, transparent 48.6%);
# }
# #T_c93ad_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 46.4%, transparent 46.4%);
# }
# #T_c93ad_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 46.2%, transparent 46.2%);
# }
# #T_c93ad_row20_col0, #T_c93ad_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 45.9%, transparent 45.9%);
# }
# #T_c93ad_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 45.7%, transparent 45.7%);
# }
# #T_c93ad_row23_col0, #T_c93ad_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 44.4%, transparent 44.4%);
# }
# #T_c93ad_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 44.2%, transparent 44.2%);
# }
# #T_c93ad_row26_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.5%, green 43.5%, green 43.7%, transparent 43.7%);
# }
# #T_c93ad_row27_col0, #T_c93ad_row28_col0 {
#   width: 10em;
# }
# #T_c93ad_row29_col0, #T_c93ad_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.1%, red 43.1%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row31_col0, #T_c93ad_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.6%, red 42.6%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row33_col0, #T_c93ad_row34_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.4%, red 42.4%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row35_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.8%, red 41.8%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row36_col0, #T_c93ad_row37_col0, #T_c93ad_row38_col0, #T_c93ad_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.5%, red 41.5%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.7%, red 40.7%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row41_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.2%, red 40.2%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row42_col0, #T_c93ad_row43_col0, #T_c93ad_row44_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.6%, red 39.6%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row45_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.1%, red 39.1%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row46_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.7%, red 38.7%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row47_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.5%, red 38.5%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row48_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.2%, red 38.2%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row49_col0, #T_c93ad_row50_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.1%, red 37.1%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row51_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 36.7%, red 36.7%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row52_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.6%, red 35.6%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row53_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.4%, red 35.4%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row54_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.9%, red 34.9%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row55_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.7%, red 34.7%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row56_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.5%, red 34.5%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row57_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.6%, red 33.6%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row58_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.7%, red 32.7%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row59_col0, #T_c93ad_row60_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.5%, red 32.5%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row61_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.3%, red 32.3%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row62_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.7%, red 29.7%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row63_col0, #T_c93ad_row64_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.0%, red 29.0%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row65_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 27.9%, red 27.9%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row66_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 27.3%, red 27.3%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row67_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.7%, red 25.7%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row68_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.3%, red 23.3%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row69_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.7%, red 16.7%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row70_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 7.9%, red 7.9%, red 43.5%, transparent 43.5%);
# }
# #T_c93ad_row71_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 43.5%, transparent 43.5%);
# }
# </style>
# <tabl
