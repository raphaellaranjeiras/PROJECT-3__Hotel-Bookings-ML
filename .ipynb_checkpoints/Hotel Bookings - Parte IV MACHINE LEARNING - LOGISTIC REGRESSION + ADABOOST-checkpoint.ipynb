# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_validate
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PowerTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from category_encoders import JamesSteinEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report
from feature_engine.encoding import RareLabelEncoder
import joblib as jb

# %%
df = pd.read_csv('hotel_bookings.csv')

# %%
df = df[~((df['arrival_date_year'] == 2015) & (df['arrival_date_month'] == 'July') | (df['arrival_date_year'] == 2017) &
         (df['arrival_date_month'] == 'August'))]
df.shape
# Out:
# (111689, 32)

# %%
df = df[~((df['children'] == 0) & (df['adults'] == 0) & (df['babies'] == 0))]
df.shape
# Out:
# (111513, 32)

# %%
df.drop(columns= ['company', 'agent', 'reservation_status_date', 'assigned_room_type', 'reservation_status',
                  'arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month'], 
        inplace= True)
df.shape
# Out:
# (111513, 24)

# %%
df.dropna(inplace= True)
df.shape
# Out:
# (111044, 24)

# %%
df.duplicated().sum()
# Out:
# 31653

# %%
df['is_canceled'].value_counts(normalize= True).mul(100).round(2)
# Out:
# 0    63.02
# 1    36.98
# Name: is_canceled, dtype: float64

# %%
df_categorical = df.select_dtypes('object')
df_numerical = df.select_dtypes('number')
# Out:
#                hotel meal country market_segment distribution_channel  \
# 82162     City Hotel   BB     PRT      Corporate            Corporate
# 12953   Resort Hotel   HB     PRT  Offline TA/TO                TA/TO
# 31360   Resort Hotel   HB     GBR         Direct               Direct
# 115771    City Hotel   BB     GBR      Online TA                TA/TO
# 63645     City Hotel   BB     PRT      Online TA                TA/TO
#
#        reserved_room_type deposit_type    customer_type
# 82162                   A   No Deposit  Transient-Party
# 12953                   E   No Deposit         Contract
# 31360                   A   No Deposit        Transient
# 115771                  F   No Deposit        Transient
# 63645                   G   No Deposit        Transient

# %%
df_categorical.shape
# Out:
# (111044, 8)

# %%
df_numerical.shape
# Out:
# (111044, 16)

# %%
X = df.drop(['is_canceled'], axis= 1)
y = df['is_canceled']

categorical_variables = X.select_dtypes('object').columns.to_list()
numerical_variables = X.select_dtypes('number').columns.to_list()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.33, random_state= 4)

# %%
df['country'].value_counts(dropna=False, normalize= True).shape
# Out:
# (175,)

# %%
df['country'].value_counts(dropna=False, normalize= True)[0:22].sum()
# Out:
# 0.9496055617593026

# %%
df['country'].value_counts(dropna=False, normalize= True)[0:22].tail()
# Out:
# ISR    0.005809
# RUS    0.005286
# NOR    0.005169
# ROU    0.004097
# FIN    0.003908
# Name: country, dtype: float64

# %%
rare_encoder = RareLabelEncoder(tol= 0.003900, variables= ['country'], replace_with= 'Other Country')
rare_encoder.fit(X_train)
X_train = rare_encoder.transform(X_train)
X_test = rare_encoder.transform(X_test)

X_train['country'].value_counts(dropna=False, normalize= True).shape
# Out:
# (23,)

# %%
X_train['country'].value_counts(dropna=False, normalize= True)
# Out:
# PRT              0.404468
# GBR              0.103536
# FRA              0.088509
# ESP              0.070565
# DEU              0.062958
# Other Country    0.051063
# ITA              0.030780
# IRL              0.028871
# BEL              0.019973
# BRA              0.019046
# NLD              0.018280
# USA              0.016694
# CHE              0.014422
# CN               0.010833
# AUT              0.010753
# SWE              0.008710
# CHN              0.008683
# POL              0.008038
# ISR              0.005497
# RUS              0.005282
# NOR              0.004839
# ROU              0.004113
# FIN              0.004086
# Name: country, dtype: float64

# %%
X_train[numerical_variables].head()
# Out:
#         lead_time  arrival_date_week_number  stays_in_weekend_nights  \
# 65992         121                        15                        0
# 110968        175                        18                        1
# 14150           4                        50                        0
# 116903         88                        30                        1
# 42135          10                        36                        2
#
#         stays_in_week_nights  adults  children  babies  is_repeated_guest  \
# 65992                      4       3       0.0       0                  0
# 110968                     3       2       0.0       0                  0
# 14150                      1       1       0.0       0                  0
# 116903                     2       2       0.0       0                  0
# 42135                      5       2       0.0       0                  0
#
#         previous_cancellations  previous_bookings_not_canceled  \
# 65992                        0                               0
# 110968                       0                               0
# 14150                        0                               5
# 116903                       0                               0
# 42135                        0                               0
#
#         booking_changes  days_in_waiting_list     adr  \
# 65992                 0                     0  173.25
# 110968                0                     0   99.00
# 14150                 0                     0   27.00
# 116903                0                     0  125.00
# 42135                 0                     0   85.00
#
#         required_car_parking_spaces  total_of_special_requests
# 65992                             0                          0
# 110968                            0                          2
# 14150                             0                          0
# 116903                            0                          1
# 42135                             0                          0

# %%
categorical_variables
# Out:
# ['hotel',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'deposit_type',
#  'customer_type']

# %%
country_variable = [categorical_variables[2]]
country_variable
# Out:
# ['country']

# %%
other_variables = []
for i in categorical_variables:
    if i not in ['country', 'reserved_room_type']:
        other_variables.append(i)
    else:
        pass
        
other_variables
# Out:
# ['hotel',
#  'meal',
#  'market_segment',
#  'distribution_channel',
#  'deposit_type',
#  'customer_type']

# %% [markdown]
# #### Testando combinação de  diferentes encoders.

# %%
def encoders_model_results_logreg(encoders_cat, encoders_country, model_):
        
    def differentencoders_model_results(x, y):
        other_variables_pipe = Pipeline([('encoder_other_variables', x)])
        country_pipe = Pipeline([('encoder_country', y)])
        num_pipe = Pipeline([('num_pwr_transf', PowerTransformer()), 
                             ('num_std_scaler', StandardScaler())])
        
        transformer = ColumnTransformer([('other_variables_transf', other_variables_pipe, other_variables),
                                         ('country_transf', country_pipe, country_variable), 
                                         ('num_transf', num_pipe, numerical_variables)])
        
        X_train_transformed = transformer.fit_transform(X_train, y_train)
        X_test_transformed = transformer.transform(X_test)
    
        cv = cross_validate(model_, X_train_transformed, y_train, cv= 10, scoring= ('recall', 'precision', 'f1'), 
                               n_jobs= -1)
        
        print(model_)
        print('Recall:', cv['test_recall'].mean().round(2), 'Precision:', 
              cv['test_precision'].mean().round(2), 'F1-Score:', cv['test_f1'].mean().round(2))
        print('')
    
    for i in encoders_cat:
        for j in encoders_country:
            print(i, ' - other variables      ', j, ' - country variable')                    
            differentencoders_model_results(i, j)

# %%
others = [OneHotEncoder(handle_unknown= 'ignore'), JamesSteinEncoder()]
country = [OneHotEncoder(handle_unknown= 'ignore'), JamesSteinEncoder()]

#Regressão Logística
encoders_model_results_logreg(others, country, LogisticRegression())
# Out:
# OneHotEncoder(handle_unknown='ignore')  - other variables       OneHotEncoder(handle_unknown='ignore')  - country variable
# LogisticRegression()
# Recall: 0.68 Precision: 0.82 F1-Score: 0.74
#
# OneHotEncoder(handle_unknown='ignore')  - other variables       JamesSteinEncoder()  - country variable
# LogisticRegression()
# Recall: 0.67 Precision: 0.82 F1-Score: 0.74
#
# JamesSteinEncoder()  - other variables       OneHotEncoder(handle_unknown='ignore')  - country variable
# LogisticRegression()
# Recall: 0.64 Precision: 0.82 F1-Score: 0.72
#
# JamesSteinEncoder()  - other variables       JamesSteinEncoder()  - country variable
# LogisticRegression()
# Recall: 0.64 Precision: 0.82 F1-Score: 0.72

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### OHE

# %%
pd.set_option('max.colwidth', None)

other_variables_pipe = Pipeline([('encoder_other_variables', OneHotEncoder(handle_unknown= 'ignore'))])
country_pipe = Pipeline([('encoder_country', OneHotEncoder(handle_unknown= 'ignore'))])
num_pipe = Pipeline([('num_pwr_transf', PowerTransformer()), 
                     ('num_std_scaler', StandardScaler())])
   
transformer = ColumnTransformer([('other_variables_transf', other_variables_pipe, other_variables),
                                 ('country_transf', country_pipe, country_variable), 
                                 ('num_transf', num_pipe, numerical_variables)])

logreg = LogisticRegression()

pipe = Pipeline([('transformer', transformer), ('model', logreg)])

weights = np.arange(0.2, 0.8, 0.005)
param_grid = {'model__class_weight':[{0:x, 1:1-x} for x in weights]}

rscv_logreg = RandomizedSearchCV(pipe, param_grid, cv= 10, n_jobs= -1, 
                    scoring= ['recall', 'precision', 'f1', 'roc_auc'], refit= 'f1', return_train_score= True, random_state= 4)

rscv_logreg.fit(X_train, y_train)

best_results = pd.DataFrame(rscv_logreg.cv_results_)

# %%
best_results[['params','mean_train_recall', 'mean_test_recall', 'mean_train_precision', 'mean_test_precision', 
              'mean_train_f1', 'mean_test_f1', 'mean_train_roc_auc', 'mean_test_roc_auc']].sort_values(
                                                                                'mean_test_f1', ascending= False).round(2)
# Out:
#                                                                      params  \
# 2   {'model__class_weight': {0: 0.3250000000000001, 1: 0.6749999999999998}}
# 7   {'model__class_weight': {0: 0.3200000000000001, 1: 0.6799999999999999}}
# 5   {'model__class_weight': {0: 0.4050000000000002, 1: 0.5949999999999998}}
# 9                  {'model__class_weight': {0: 0.3000000000000001, 1: 0.7}}
# 4   {'model__class_weight': {0: 0.2950000000000001, 1: 0.7049999999999998}}
# 3                 {'model__class_weight': {0: 0.2800000000000001, 1: 0.72}}
# 0  {'model__class_weight': {0: 0.26500000000000007, 1: 0.7349999999999999}}
# 6  {'model__class_weight': {0: 0.22500000000000003, 1: 0.7749999999999999}}
# 1                {'model__class_weight': {0: 0.21000000000000002, 1: 0.79}}
# 8   {'model__class_weight': {0: 0.6100000000000003, 1: 0.3899999999999997}}
#
#    mean_train_recall  mean_test_recall  mean_train_precision  \
# 2               0.82              0.82                  0.71
# 7               0.83              0.83                  0.71
# 5               0.76              0.76                  0.76
# 9               0.84              0.84                  0.69
# 4               0.85              0.84                  0.69
# 3               0.86              0.86                  0.67
# 0               0.87              0.87                  0.66
# 6               0.90              0.90                  0.63
# 1               0.91              0.91                  0.62
# 8               0.59              0.59                  0.88
#
#    mean_test_precision  mean_train_f1  mean_test_f1  mean_train_roc_auc  \
# 2                 0.71           0.76          0.76                 0.9
# 7                 0.71           0.76          0.76                 0.9
# 5                 0.76           0.76          0.76                 0.9
# 9                 0.69           0.76          0.76                 0.9
# 4                 0.69           0.76          0.76                 0.9
# 3                 0.67           0.75          0.75                 0.9
# 0                 0.66           0.75          0.75                 0.9
# 6                 0.63           0.74          0.74                 0.9
# 1                 0.61           0.73          0.73                 0.9
# 8                 0.88           0.70          0.70                 0.9
#
#    mean_test_roc_auc
# 2                0.9
# 7                0.9
# 5                0.9
# 9                0.9
# 4                0.9
# 3                0.9
# 0                0.9
# 6                0.9
# 1                0.9
# 8                0.9

# %%
print(rscv_logreg.best_params_)
print('')

y_pred = rscv_logreg.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
# {'model__class_weight': {0: 0.3250000000000001, 1: 0.6749999999999998}}
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84     23067
#            1       0.71      0.83      0.77     13578
#
#     accuracy                           0.81     36645
#    macro avg       0.80      0.82      0.80     36645
# weighted avg       0.82      0.81      0.81     36645

# %% [markdown]
# - Percebe-se que o modelo generalizou de forma consistente quando foi alimentado com os dados responsáveis para simular o modelo em produção. Os valores se manteram bastante próximos das métricas de teste.

# %% [markdown]
# ####  OHE + JamesStein

# %%
other_variables_pipe = Pipeline([('encoder_other_variables', OneHotEncoder(handle_unknown= 'ignore'))])
country_pipe = Pipeline([('encoder_country', JamesSteinEncoder())])
num_pipe = Pipeline([('num_pwr_transf', PowerTransformer()), 
                     ('num_std_scaler', StandardScaler())])
   
transformer = ColumnTransformer([('other_variables_transf', other_variables_pipe, other_variables),
                                 ('country_transf', country_pipe, country_variable), 
                                 ('num_transf', num_pipe, numerical_variables)])

logreg = LogisticRegression()

pipe = Pipeline([('transformer', transformer), ('model', logreg)])

weights = np.arange(0.2, 0.8, 0.005)
param_grid = {'model__class_weight':[{0:x, 1:1-x} for x in weights]}

rscv_logreg_jss = RandomizedSearchCV(pipe, param_grid, cv= 10, n_jobs= -1, 
                    scoring= ['recall', 'precision', 'f1', 'roc_auc'], refit= 'f1', return_train_score= True, random_state= 4)

rscv_logreg_jss.fit(X_train, y_train)

best_results = pd.DataFrame(rscv_logreg_jss.cv_results_)

# %%
best_results[['params','mean_train_recall', 'mean_test_recall', 'mean_train_precision', 'mean_test_precision', 
              'mean_train_f1', 'mean_test_f1', 'mean_train_roc_auc', 'mean_test_roc_auc']].sort_values(
                                                                                'mean_test_f1', ascending= False).round(2)
# Out:
#                                                                      params  \
# 2   {'model__class_weight': {0: 0.3250000000000001, 1: 0.6749999999999998}}
# 7   {'model__class_weight': {0: 0.3200000000000001, 1: 0.6799999999999999}}
# 5   {'model__class_weight': {0: 0.4050000000000002, 1: 0.5949999999999998}}
# 9                  {'model__class_weight': {0: 0.3000000000000001, 1: 0.7}}
# 4   {'model__class_weight': {0: 0.2950000000000001, 1: 0.7049999999999998}}
# 3                 {'model__class_weight': {0: 0.2800000000000001, 1: 0.72}}
# 0  {'model__class_weight': {0: 0.26500000000000007, 1: 0.7349999999999999}}
# 6  {'model__class_weight': {0: 0.22500000000000003, 1: 0.7749999999999999}}
# 1                {'model__class_weight': {0: 0.21000000000000002, 1: 0.79}}
# 8   {'model__class_weight': {0: 0.6100000000000003, 1: 0.3899999999999997}}
#
#    mean_train_recall  mean_test_recall  mean_train_precision  \
# 2               0.82              0.82                  0.71
# 7               0.82              0.82                  0.70
# 5               0.75              0.75                  0.76
# 9               0.84              0.84                  0.69
# 4               0.84              0.84                  0.68
# 3               0.86              0.86                  0.67
# 0               0.87              0.87                  0.66
# 6               0.90              0.90                  0.62
# 1               0.91              0.91                  0.61
# 8               0.58              0.58                  0.88
#
#    mean_test_precision  mean_train_f1  mean_test_f1  mean_train_roc_auc  \
# 2                 0.71           0.76          0.76                 0.9
# 7                 0.70           0.76          0.76                 0.9
# 5                 0.76           0.76          0.76                 0.9
# 9                 0.69           0.76          0.76                 0.9
# 4                 0.68           0.76          0.75                 0.9
# 3                 0.67           0.75          0.75                 0.9
# 0                 0.66           0.75          0.75                 0.9
# 6                 0.62           0.74          0.74                 0.9
# 1                 0.61           0.73          0.73                 0.9
# 8                 0.88           0.70          0.70                 0.9
#
#    mean_test_roc_auc
# 2                0.9
# 7                0.9
# 5                0.9
# 9                0.9
# 4                0.9
# 3                0.9
# 0                0.9
# 6                0.9
# 1                0.9
# 8                0.9

# %%
print(rscv_logreg_jss.best_params_)
print('')

y_pred = rscv_logreg_jss.predict(X_test)

print(classification_report(y_test, y_pred))

pd.reset_option('max.colwidth')
# Out:
# {'model__class_weight': {0: 0.3250000000000001, 1: 0.6749999999999998}}
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84     23067
#            1       0.71      0.82      0.76     13578
#
#     accuracy                           0.81     36645
#    macro avg       0.80      0.81      0.80     36645
# weighted avg       0.82      0.81      0.81     36645

# %%
jb.dump(rscv_logreg, 'logistic_regression_model')
# Out:
# ['logistic_regression_model']

# %% [markdown]
# ### Análise das Features  do modelo

# %%
feature_importance = pd.DataFrame(rscv_logreg.best_estimator_['model'].coef_.T, columns= ['importance'], 
                                  index= rscv_logreg.best_estimator_['transformer'].get_feature_names_out())
feature_importance.sort_values('importance', ascending= False).round(2).style.bar(color=['red', 'green'])
# Out:
# <style type="text/css">
# #T_1e45f_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 100.0%, transparent 100.0%);
# }
# #T_1e45f_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 86.1%, transparent 86.1%);
# }
# #T_1e45f_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 70.3%, transparent 70.3%);
# }
# #T_1e45f_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 65.0%, transparent 65.0%);
# }
# #T_1e45f_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 61.2%, transparent 61.2%);
# }
# #T_1e45f_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 60.8%, transparent 60.8%);
# }
# #T_1e45f_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 56.8%, transparent 56.8%);
# }
# #T_1e45f_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 56.6%, transparent 56.6%);
# }
# #T_1e45f_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 54.4%, transparent 54.4%);
# }
# #T_1e45f_row9_col0, #T_1e45f_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 53.7%, transparent 53.7%);
# }
# #T_1e45f_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 53.1%, transparent 53.1%);
# }
# #T_1e45f_row12_col0, #T_1e45f_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 52.0%, transparent 52.0%);
# }
# #T_1e45f_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 50.9%, transparent 50.9%);
# }
# #T_1e45f_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 50.4%, transparent 50.4%);
# }
# #T_1e45f_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 49.6%, transparent 49.6%);
# }
# #T_1e45f_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 48.7%, transparent 48.7%);
# }
# #T_1e45f_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 46.5%, transparent 46.5%);
# }
# #T_1e45f_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 45.8%, transparent 45.8%);
# }
# #T_1e45f_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 44.5%, transparent 44.5%);
# }
# #T_1e45f_row21_col0, #T_1e45f_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 44.3%, transparent 44.3%);
# }
# #T_1e45f_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.6%, green 43.6%, green 44.1%, transparent 44.1%);
# }
# #T_1e45f_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.4%, red 43.4%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.2%, red 43.2%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row26_col0, #T_1e45f_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.5%, red 42.5%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row28_col0, #T_1e45f_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 42.3%, red 42.3%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.9%, red 41.9%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.6%, red 41.6%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.4%, red 41.4%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.7%, red 40.7%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row34_col0, #T_1e45f_row35_col0, #T_1e45f_row36_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.6%, red 39.6%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row37_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.0%, red 39.0%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row38_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.8%, red 38.8%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.5%, red 38.5%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 38.3%, red 38.3%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row41_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.0%, red 37.0%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row42_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 36.8%, red 36.8%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row43_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.9%, red 35.9%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row44_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 35.7%, red 35.7%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row45_col0, #T_1e45f_row46_col0, #T_1e45f_row47_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.8%, red 34.8%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row48_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.7%, red 33.7%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row49_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.8%, red 32.8%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row50_col0, #T_1e45f_row51_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.6%, red 32.6%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row52_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.4%, red 32.4%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row53_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.5%, red 29.5%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row54_col0, #T_1e45f_row55_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.1%, red 29.1%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row56_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 28.0%, red 28.0%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row57_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 27.1%, red 27.1%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row58_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 25.6%, red 25.6%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row59_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.6%, red 23.6%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row60_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.3%, red 16.3%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row61_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 7.9%, red 7.9%, red 43.6%, transparent 43.6%);
# }
# #T_1e45f_row62_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, red 43.6%, transparent 43.6%);
# }
# </style>
# <table id="T_1e45f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e45f_level0_col0" class="col_heading level0 col0" >importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e45f_level0_row0" class="row_heading level0 row0" >other_variables_transf__deposit_type_Non Refund</th>
#       <td id="T_1e45f_row0_col0" class="data row0 col0" >2.560000</td>
#     </tr>
#     <tr>
#       <th id="T_1e45f_level0_row1" class="row_heading level0 row1" >country_transf__country_PRT</th>
#       <td id="T_1e45f_row1_col0" class="data row

# %% [markdown]
# ### AdaBoostClassifier | Estimador Base: Logistic Regression

# %%
categorical_variables_pipe = Pipeline([('encoder_categorical_variables', OneHotEncoder(handle_unknown= 'ignore'))])
num_pipe = Pipeline([('num_pwr_transf', PowerTransformer()), 
                     ('num_std_scaler', StandardScaler())])
   
transformer = ColumnTransformer([('ohe', OneHotEncoder(handle_unknown= 'ignore'), categorical_variables),
                                 ('pwr', PowerTransformer(), numerical_variables),
                                 ('stdscaler', StandardScaler(), numerical_variables)])

ada_logreg = AdaBoostClassifier(LogisticRegression(class_weight= {0:0.325, 1:0.675}), n_estimators= 100, random_state=4)

pipe = Pipeline([('transformer', transformer), ('model', ada_logreg)])

param_grid = {'model__learning_rate': np.arange(1, 1.5, 0.05)}   
    
rscv_ada_logreg = RandomizedSearchCV(pipe, param_grid, cv= 10, n_jobs= -1, scoring= ['recall', 'precision', 'f1', 'roc_auc'], 
                             refit= 'f1', return_train_score= True, random_state= 4)

rscv_ada_logreg.fit(X_train, y_train)

best_results = pd.DataFrame(rscv_ada_logreg.cv_results_)

# %%
pd.set_option('max.colwidth', None)
best_results[['params','mean_train_recall', 'mean_test_recall', 'mean_train_precision', 'mean_test_precision', 
              'mean_train_f1', 'mean_test_f1', 'mean_train_roc_auc', 'mean_test_roc_auc']].sort_values(
                                                                                'mean_test_f1', ascending= False).round(2)
# Out:
#                                          params  mean_train_recall  \
# 8  {'model__learning_rate': 1.4000000000000004}               0.82
# 7  {'model__learning_rate': 1.3500000000000003}               0.82
# 9  {'model__learning_rate': 1.4500000000000004}               0.82
# 6  {'model__learning_rate': 1.3000000000000003}               0.82
# 5  {'model__learning_rate': 1.2500000000000002}               0.82
# 4  {'model__learning_rate': 1.2000000000000002}               0.82
# 3  {'model__learning_rate': 1.1500000000000001}               0.82
# 2                 {'model__learning_rate': 1.1}               0.82
# 1                {'model__learning_rate': 1.05}               0.82
# 0                 {'model__learning_rate': 1.0}               0.82
#
#    mean_test_recall  mean_train_precision  mean_test_precision  mean_train_f1  \
# 8              0.82                   0.7                  0.7           0.76
# 7              0.82                   0.7                  0.7           0.76
# 9              0.82                   0.7                  0.7           0.76
# 6              0.82                   0.7                  0.7           0.76
# 5              0.82                   0.7                  0.7           0.76
# 4              0.82                   0.7                  0.7           0.76
# 3              0.82                   0.7                  0.7           0.75
# 2              0.82                   0.7                  0.7           0.75
# 1              0.82                   0.7                  0.7           0.75
# 0              0.82                   0.7                  0.7           0.75
#
#    mean_test_f1  mean_train_roc_auc  mean_test_roc_auc
# 8          0.76                 0.9                0.9
# 7          0.76                 0.9                0.9
# 9          0.76                 0.9                0.9
# 6          0.76                 0.9                0.9
# 5          0.76                 0.9                0.9
# 4          0.75                 0.9                0.9
# 3          0.75                 0.9                0.9
# 2          0.75                 0.9                0.9
# 1          0.75                 0.9                0.9
# 0          0.75                 0.9                0.9

# %%
print(rscv_ada_logreg.best_params_)
print('')

y_pred = rscv_ada_logreg.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# {'model__learning_rate': 1.4000000000000004}
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.84     23067
#            1       0.70      0.82      0.76     13578
#
#     accuracy                           0.80     36645
#    macro avg       0.79      0.81      0.80     36645
# weighted avg       0.82      0.80      0.81     36645

# %% [markdown]
# - Percebe-se que o modelo generalizou de forma consistente quando foi alimentado com os dados responsáveis para simular o modelo em produção. Os valores se manteram bastante próximos das métricas de teste.

# %%
jb.dump(value= rscv_ada_logreg, filename= 'ada_logreg_model')
# Out:
# ['ada_logreg_model']
